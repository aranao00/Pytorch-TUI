# %%
import torch.nn as nn
import torch
import json
'''
error code list:
14: No architecture detected
15: No version code detected
'''

#def dataload(): #사용자 설정 데이터 로더.

class Architecture_Database():#아키텍처별로 코드 따로 저장하게 나중에 바꿔보기. 그리고 가중치 유지한채로 코드 바꾸는것도 지원하게.
#+모델 순서나 concate등의 사용도 자유롭게 설정할 수 있게 .
    def __init__(self):
        #아키텍처는 사용자가 해당 모델의 구조를 확인하기 쉽도록 하는 json 파일.
        #code는 실제로 아키텍처와 가중치가 저장되는 json 파일.

        self.code_dictionary=None
        self.architecture_dictionary=None
        self.weight=None
        self.load_db()
        self.models=None
    def save(self):
        #모델 별 아키텍처 이름과 instance 저장.
        with open('code_list.json', 'w') as file:
            json.dump(self.code_dictionary, file)
        with open('architectures.json', 'w') as file:
            json.dump(self.architecture_dictionary, file)
        return 0
    
    def load_db(self):
        #모델 별 아키텍처/instace 저장.
        with open('code_list.json', 'r') as file:
            self.code_dictionary = json.load(file)
        with open('architectures.json', 'r') as file:
            self.architecture_dictionary = json.load(file)

    def load_mod(self, code):#Done.
        #instance 로드.
        version_name=self.code_dictionary[code]
        if self.weight==False:
            print(f'No version named \'{code}\'')
            return 15
        model=torch.load(f"{code}.pth")
        return model

    def modify_model(self, name, architecture):
        #모델 아키텍처 수정.
        return 0
    
    def load_architecture(self, layers, forward_func):
        layerlen=len(layers)
        model=nn.ModuleList([])
        for i in range(layerlen):
            try:
                instant_module = globals()[f"nn.{layers[i][0]}"]
                model.append(instant_module(layers[i][1]))
            except KeyError:
                instant_module=self.load_architecture(self.architecture_dictionary[layers[i][0]])
                if instant_module==False:
                    print(f"No Module or Architecture named \'{layers[i]}\'")
                    return 14
        return model


    def load_arch(self, name):
        #architecture를 바탕으로 새로 초기화한 instance를 반환.

    def modify_forward(self):





class main_ui():
    def __init__(self):
        super(main_ui, self).__init__()
        self.model=nn.ModuleDict([])
        self.architecture=[]
        self.visualize=False#Default
        self.cude=torch.cuda.is_available()#Default
        self.db=Architecture_Database()

    def setmod(self, modname=None, sourcename=None, versioncode=None):
        if sourcename==None:
            self.modsource=input('model source name:')
        else:
            self.modsource=sourcename
            print(f'model source name:{sourcename}')

        if modname==None:
            self.modclass=input('model class name:')
        else:
            self.modname=modname
            print(f'model class name:{modname}')

        loader=getattr(sourcename, modname)
        self.model=loader()
        if versioncode==None:
            self.modcode=input('model version code:')
        else:
            self.modcode=versioncode
            print(f'model version code:{versioncode}')
        self.model.load_state_dict(torch.load(f"{self.modcode}.pth"))
        return self.model

    def savemod(self):
        torch.save(self.model.state_dict(), f'{self.modcode}.pth')
        return 0

    def set_option(self, optname, lrset=0.0001):
        loader=getattr('nn', optname)
        self.optim=loader(self.model.parameters(), lrset)
        return 0

    def training(self):

    def start(self):
        self.setmod()
        self.set_option()
        cycle=input('save cycle:')
        epoch=input('train epoch:')
        print('Batch size: default (1)')
# Out:
# uns
